# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import scienceplots
plt.style.use(['science', 'no-latex'])

import os
import sys
sys.path.append(os.path.abspath('.'))
from src.plots import set_size

# %%
# from: logs_adversarial_blackbox_onehot_nl2bash\out.txt
adv_payload_size_vs_evasive = {0: 2, 16: 23, 32: 32, 64: 47, 128: 73}

# show curves with different payload sizes and number of evasive techniques
# x -- payload size (keys of adv_payload_size_vs_evasive)
# y -- number of evasive techniques (values of adv_payload_size_vs_evasive)
# plot -- scatter plot with dashed line between scatter points (x, y) and (x, x)

fig, ax = plt.subplots(figsize=set_size())
ax.scatter(adv_payload_size_vs_evasive.keys(), adv_payload_size_vs_evasive.values(), s=100, color='black')
ax.plot(adv_payload_size_vs_evasive.keys(), adv_payload_size_vs_evasive.values(), '--', color='black')
ax.set_xlabel('Payload size (bytes)', fontsize=14)
ax.set_ylabel('Number of evasive techniques', fontsize=14)
# ax.set_xlim(0, 128)
# ax.set_ylim(0, 128)
# Out:
# Text(0, 0.5, 'Number of evasive techniques')
